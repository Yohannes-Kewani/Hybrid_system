# %% [markdown]
# **Introduction**
#
# Although Ethiopia is consistently expanding its national power generation capabilities, a significant disparity remains in electricity access, particularly among unserved communities. Statistical data reveals that approximately 80% to 85% of the Ethiopian population resides in rural hinterlands, where the infrastructure required for grid connectivity is currently nonexistent. Due to the dispersed settlement patterns of these rural homesteads, extending the national grid to reach them is not economically feasible in the short to medium term. To overcome this bottleneck in energy delivery, harnessing the country's abundant untapped renewable potentials—specifically wind and solar resources—is essential for resolving the energy crisis in rural communities and enhancing their socio-economic well-being.
#
# For this hybrid micro-grid design and performance analysis, the selected site is the rural vicinity of Mekelle City, located approximately 780 km north of the capital, Addis Ababa. The Mekelle area is well-identified for its high solar radiation intensity and significant wind energy potential. This potential is evidenced by the presence of the Ashegoda Wind Farm in the immediate vicinity. However, much like other large-scale projects, the Ashegoda station feeds its generated power directly into the National Grid (ICS), leaving the surrounding rural villages without access to the energy generated in their own backyard.
#
# Therefore, the primary objective of this study is to design and conduct a performance analysis of an isolated hybrid Micro-Grid power supply system using HOMER Pro. The aim is to deliver a reliable and cost-effective electric supply to a rural village near Mekelle. The proposed hybrid system integrates Wind Turbine Generators, Diesel Generators, and Solar PV panels. A distinct feature of this specific design analysis is the intentional exclusion of battery storage or other energy storage technologies. This strategy has been adopted to significantly minimize the system's Net Present Cost (NPC) and initial capital expenditure. The geographical location of the study area, as retrieved via the HOMER software mapping tool, is illustrated in Figure 1.

# %% [markdown]
# ![Location](Mekelle_area.png)
# **Figure 1:** Hybrid micro-grid system architecture for Mekelle area

# %% [markdown]
# The following parameters are set before starting the design
# process:
# * Discount rate (%)…….8
# * Inflation rate (%)…….4
# * Annual capacity shortage (%)….20
# * Project life time (years)…….25

# %% [markdown]
# **1.1 Current and Forecasted Load Profile**
#
# The electrical load data for this study was established through a combination of direct on-site field surveys and empirical analysis of the target rural village. The assessment defines the current AC load baseline and projects demand growth over 10-year and 15-year horizons.
#
# The design scope encompasses 100 households as the primary residential load. In addition to domestic consumption, the micro-grid is sized to support a significant agricultural load: two AC water pumps, each with a rated capacity of 100 kW, utilized for community irrigation. The operational schedule for these pumps is distinct, limited to a two-hour duration in the morning and a two-hour duration in the evening.
#
# The comprehensive daily load profiles, representing the current baseline as well as the forecasted scenarios for the 10-year and 15-year milestones, are detailed in Table 1 below.

# %% [markdown]
# **Table 1.** Current and Forecasted Daily Load profile data of the rural village
# | Hour | Present Load in KW | Forecasted load after 10 Years in KW | Forecasted load after 10 Years in KW |
# |----------|----------|----------|------|
# | 0 | 250 | 500 | 750 |
# | 1 | 250 | 500 | 750 |
# | 2 | 250 | 500 | 750 |
# | 3 | 25 | 50 | 75 |
# | 4 | 25 | 50 | 75 |
# | 5 | 25 | 50 | 75 |
# | 6 | 50 | 100 | 150 |
# | 7 | 50 | 100 | 150 |
# | 8 | 50 | 100 | 150 |
# | 9 | 10 | 20 | 40 |
# | 10 | 10 | 20 | 40 |
# | 11 | 10 | 20 | 40 |
# | 12 | 250 | 500 | 750 |
# | 13 | 250 | 500 | 750 |
# | 14 | 250 | 500 | 750 |
# | 15 | 50 | 100 | 150 |
# | 16 | 5 | 10 | 15 |
# | 17 | 5 | 10 | 15 |
# | 18 | 5 | 10 | 15 |
# | 19 | 5 | 10 | 15 |
# | 20 | 0 | 5 | 10 |
# | 21 | 0 | 5 | 10 |
# | 22 | 10 | 20 | 30 |
# | 23 | 10 | 20 | 30 |

# %% [markdown]
# The baseline load data was input into the HOMER software using January as the representative peak month. The resulting generated profiles—Daily, Seasonal, and Yearly—are illustrated in Figures 2, 3, and 4 respectively. To simulate realistic grid fluctuations, a day-to-day random variability of 10% and a time-step variability of 20% were applied to the model.
#
# According to the simulation outputs, the system demonstrates a scaled annual average energy consumption of 1,845 kWh/day , corresponding to an average continuous power demand of 76.87 kW . As depicted in the Daily Profile, the load is characterized by two distinct high-demand interval occurring from 00:00 to 03:00 and 12:00 to 15:00 , where the power usage spikes to a maximum. Consequently, the peak power requirement is approximately 250 kW , resulting in a system load factor of 0.31 . All power demands within the micro-grid are modeled as AC loads.

# %% [markdown]
# ![daily_profile](daily_load_profile.png)
# **Figure 2:** Mekelle daily load profile

# %% [markdown]
# ![seasonal_load_profile](seasonal_load_profile.png)
# **Figure 3:** Mekelle seasonal load profile

# %% [markdown]
# ![yearly_load_profile](yearly_load_profile.png)
#
# **Figure 4:** Mekelle Yearly load profile

# %% [markdown]
# **2 LITERATURE Review**
#
# Global electricity consumption continues to escalate, creating an urgent need for sustainable power solutions as fossil fuel reserves diminish. To mitigate reliance on conventional energy and address the inherent intermittency of standalone renewable technologies—such as solar photovoltaic (PV) or wind turbines—researchers increasingly advocate for hybrid off-grid systems. For instance, the design and performance analysis conducted for a rural village in the Adama area, Ethiopia [1], utilizes a hybrid approach to overcome resource variability, demonstrating the necessity of integrating multiple generation sources for reliable rural electrification.
#
# To effectively engineer these complex systems, the Hybrid Optimization of Multiple Energy Resources (HOMER) software serves as a critical tool. HOMER simplifies the evaluation of both off-grid and grid-connected configurations by modeling various inputs, including conventional generators, wind turbines, solar PV, hydropower, batteries, and biomass [2]. As highlighted in the methodology of [1], the software performs a rigorous economic analysis, calculating the total Net Present Cost (NPC), operational costs, and the Levelized Cost of Energy (COE) to identify the optimal system architecture [3]. Ultimately, these simulations support the development of robust micro-grids—localized power networks that aggregate distributed generation resources (DGR) ranging from solar arrays and wind converters to biodiesel generators and micro-turbines [4].

# %% [markdown]
# **3  RESOURCES USED IN THE DESIGN PROCESS**
#
# **3.1 Solar Global Horizontal Irradiance (GHI ) resource**
#
# ![Monthly_Average_GHI](Monthly_Average_GHI.png)
#
# **Table 2** Monthly Average solar Global Horizontal irradiance (GHI) data for the design area
# (Internet source: National renewable energy Lab database)

# %% [markdown]
# ![Monthly_Average_Solar_GHI](Monthly_Average_Solar_GHI.png)
#
# **Figure 5**Monthly average solar global horizontal irradiance (GHI) data for the design area
# (Internet source: National renewable energy Lab database)

# %% [markdown]
# **3.2 Temperature resource**
#
# ![Monthly_Average_Temperature](Monthly_Average_Temperature.png)
#
# **Table 3** Monthly average temperature data for the design area
# (Internet source: NASA surface meteorology and solar energy database)

# %% [markdown]
# ![Monthly_Average_T](Monthly_Average_T.png)
#
# **Figure 6: **Monthly average temperature data for the design area
# (Internet source: NASA surface meteorology and solar energy database)

# %% [markdown]
# **3.3 Wind Resource**
#
# ![Monthly_Average_Wind_Speed](Monthly_Average_Wind_Speed.png)
#
# **Table 4:** Monthly average wind speed data for the design area
# (Internet source: NASA surface meteorology and solar energy database)

# %% [markdown]
# ![Monthly_Average_WS](Monthly_Average_WS.png)
#
# **Figure 7:** Monthly average wind speed data for the design area

# %% [markdown]
# **4 MODELLING OF THE HYBRID SYSTEM IN HOMER SOFTWARE**
#
# ![Model_of_Hybrid](Model_of_Hybrid.png)
#
# **Figure 8:** Model of the hybrid system in HOMER

# %% [markdown]
# ![Simulation_Results](Simulation_Results.png)
#
# **Figure 9:** simulation result

# %% [markdown]
# The operational longevity and economic parameters of the system components have been defined to ensure a realistic lifecycle analysis within the HOMER model. The designated lifespans for the primary hardware are as follows:
#
# - Diesel Generator: 15,000 operational hours.
#
# - Solar PV Modules: 25 years.
#
# - Wind Turbines: 20 years.
#
# - PV Inverters: 15 years.
#
# For the fuel resource input, the diesel price is established at 150 Birr/liter, which is the local equivalent of 87 Rupees/liter.

# %% [markdown]
# | S/No | Equipment | Capital Cost in Birr per KW | Replacement cost in Birr per KW | O&M in Birr per Year|
# |----------|----------|----------|------|-----|
# | 1 |Generator | 250 | 200| 0.05|
# | 2 | Solar Panel | 150 | 100 |50 |
# | 3 | Wind Turbine | 250 | 200 |100|
# | 4 | Inverter | 100 | 75 |50|
#
# **Table 5:** Cost estimate in Ethiopian birr of different equipment for the designed hybrid system

# %% [markdown]
# **5. ANALYSIS OF SIMULATION RESULTS**
#
# The simulation results demonstrate that the integrated Wind-PV-Diesel hybrid configuration is the most reliable and cost-effective architecture for meeting the energy demands of the rural Mekelle community. This optimized system outperformed alternative combinations—such as Solar-Diesel, Wind-Diesel, and standalone Diesel generation—in terms of both technical stability and long-term economic viability.
#
# A comprehensive analysis of the Wind-PV-Diesel system was conducted, evaluating key performance indicators including component-level cost summaries, life-cycle cash flows, and comparative economic metrics. Additionally, the study assesses the electrical contribution of each power source and fuel consumption efficiency. The following sections provide a visual and quantitative breakdown of these parameters to illustrate the system's performance.

# %% [markdown]
# ![Cost_summary](Cost_summary.png)
#
# **Figure 10:** Cost summary

# %% [markdown]
# ![Discounted_Cash_Flow](Discounted_Cash_Flow.png)
#
# **Figure 11:** Nominal Cash Flow by component type

# %% [markdown]
# ![Economic_comparison](Economic_comparison.png)
#
# **Figure 12:** Economics comparison

# %% [markdown]
# ![Monthly_Electric_production](Monthly_Electric_Production.png)
#
# **Figure 13:** Monthly average electric production

# %% [markdown]
# **6. CONCLUSION AND RECOMMENDATIONS**
#
# Based on the HOMER Pro simulation results for the rural Mekelle site, it is concluded that a hybrid configuration integrating wind turbines, solar PV, and a diesel generator represents the most economically viable and technically reliable solution. This tri-hybrid architecture significantly outperforms standalone diesel generation or dual-source systems (Solar-Diesel or Wind-Diesel) in meeting the rigorous 250 kW peak demand of the village. The synergy between Mekelle’s highland wind patterns and high solar irradiance ensures a stable power supply, even in the absence of a battery storage system.
#
# A critical finding of this study is the significant volume of excess energy generated during peak production hours. Given that this design intentionally excludes storage to minimize capital costs, this surplus power presents a strategic opportunity. It can be utilized to accommodate the forecasted load growth over the next 10 to 15 years, as detailed in the village expansion projections in Table 1. Furthermore, this capacity margin provides a buffer for the anticipated increase in residential demand and potential future commercial activities within the community.

# %%
**7 REFERENCES**
  
[1]. R. Srivastava and V.K.Giri, Optimization of Hybrid Renewable Resources using HOMER, international journal of renewable energy research, Vol.6, No.1,
2016.
[2]. Kenneth E. Okedu, Roland Uhunmwangho,
Optimization of Renewable Energy Efficiency using
HOMER, Article in International Journal of
Renewable Energy Research, Vol. 4, No. 2,
2014.
[3]. Kamlesh Pandey, Priya Banerjee and Devavrat
Mathur, Study and Modelling of Green Energy based
Micro-Grid for Rural Area, Indian Journal of Science
and Technology, Vol 9(21), June 2016.
[4]. Optimization analysis of Microgrid using HOMER —
a case study,Conference Paper December 2011.
[5]. B. Kroposki, R. Lasseter, T. Ise, S. Morozumi, S.
Papathanassiou, and Nikos Hatziargyriou,
Microgrids: Technologies and Testing, IEEE Power
and Energy Magazine, May2008.
